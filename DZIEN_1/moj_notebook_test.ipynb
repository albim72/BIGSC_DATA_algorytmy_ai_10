# %%
print("to jest pierwszy notebook Datalore!")
# Out:
# to jest pierwszy notebook Datalore!

# %%
a = 101
b = 3.88
a+b
# Out:
# 104.88

# %%
d = 7*a-2*b
e = 6
x = d*e
x
# Out:
# 4195.4400000000005

# %% [markdown]
# To jest komórka z opisem - mogę ją użyc w **formatach**:
# <span style="color:red;font-size:16pt;">html, jpg, pdf ...</span>
# <br>
# <table border="1" style="border-collapse:collapse;width=100%;text-align:left;">
# <thead>
# <tr><th>id</th><th>nazwa</th></tr>
# </thead>
# <tbody>
# <tr><td>1</td><td>miernik powietrza</td></tr>
# <tr><td>2</td><td>miernik wody</td></tr>
# </tbody>

# %%
lsztuk = 8

# %%
cena = "11.6"

# %%
lsztuk*float(cena)
# Out:
# 92.8
